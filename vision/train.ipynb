# %%
from roboflow import Roboflow
rf = Roboflow(api_key="wDZXF4RTc31mYOMagYRB")
project = rf.workspace("te-xkrgm").project("tictactoe-kpr4t")
dataset = project.version(4).download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to tictactoe-4 in yolov8:: 100%|██████████| 236/236 [00:00<00:00, 18246.19it/s]

# %%
# !yolo task=detect \
mode=train \
model=yolov8s.pt \
data={dataset.location}/data.yaml \
epochs=100 \
imgsz=640
# Out:
# New https://pypi.org/project/ultralytics/8.0.203 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.134 🚀 Python-3.11.5 torch-2.1.0+cu121 CUDA:0 (NVIDIA GeForce RTX 3060, 12042MiB)
# ...
